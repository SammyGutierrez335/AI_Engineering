# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")
else:
    print("Hello World!")

client = OpenAI()
# Out:
# Hello World!

# %%
load_dotenv
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")
else:
    print("Hello World!")

client = OpenAI()
# Out:
# Hello World!

# %% [markdown]
# ### Call the API

# %%
responses = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{
        "role": "user", "content": "Hi there my, name is Sammy"
    }]
)

reply = responses.choices[0].message.content

print(responses)
# Out:
# ChatCompletion(id='chatcmpl-EG5uIIqnH1fw9uKi244wUkSIdlSZW', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Hello Sammy! How can I assist you today?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787504662, model='gpt-4.1-mini-2025-04-14', object='chat.completion', metadata=None, moderation=None, service_tier='default', system_fingerprint='fp_1407d13508', usage=CompletionUsage(completion_tokens=10, prompt_tokens=14, total_tokens=24, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=None, cached_tokens=0, image_tokens=None, text_tokens=None)))

# %% [markdown]
# ### Step 3a - Calling the API with a System Prompt

# %%
responses = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{
        "role": "system", "content": "You are a 5 star restaurant chef assisting other 5 star chef's how to cook your award winning pasta", #system prompt
        "role": "user", "content": "How do I cook pasta?"
    }]
)

reply = responses.choices[0].message.content

print(reply)
# Out:
# Cooking pasta is easy! Here’s a simple step-by-step guide:
#
# 1. **Boil water:** Fill a large pot with water, about 4-6 quarts per pound of pasta. Add a good amount of salt (about 1-2 tablespoons) to the water—this flavors the pasta.
#
# 2. **Bring to a boil:** Heat the water on high until it’s rolling boiling.
#
# 3. **Add pasta:** Put the pasta into the boiling water and stir immediately to prevent sticking.
#
# 4. **Cook:** Boil the pasta uncovered. Check the package for the recommended cooking time, usually 8-12 minutes. Stir occasionally.
#
# 5. **Test for doneness:** Taste a piece a minute or two before the suggested time to see if it’s al dente (firm to the bite) or cooked to your preference.
#
# 6. **Drain:** Once done, pour the pasta into a colander to drain the water. Avoid rinsing unless making a cold pasta salad or storing it for later.
#
# 7. **Serve:** Toss the pasta with your preferred sauce or ingredients and enjoy!
#
# ...
