# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")
else:
    print("Hello World!")
# Out:
# sk-proj-

# %% [markdown]
# ### Call the API

# %%
client = OpenAI()

responses = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{
        "role": "user", "content": "what is an Okapi?"
    }]
)

answer = responses.choices[0].message.content

print(answer)
# Out:
# An **Okapi** is a unique mammal native to the dense rainforests of the Democratic Republic of Congo in Central Africa. It is often described as a close relative of the giraffe, although it looks quite different. Key facts about the okapi include:
#
# - **Scientific name:** *Okapia johnstoni*
# - **Appearance:** The okapi has a body shape somewhat similar to a giraffe but much shorter neck. It has velvety dark brown or reddish-brown fur, with striking horizontal white and black stripes on its legs and buttocks, which help with camouflage in the forest.
# - **Size:** About 1.5 to 2 meters (5 to 6.5 feet) long and weighs around 200 to 350 kilograms (440 to 770 pounds).
# - **Habitat:** Dense tropical rainforests in the Congo Basin.
# - **Diet:** Herbivorous, feeding on leaves, buds, grasses, fruits, and fungi.
# - **Behavior:** Solitary and elusive, the okapi uses its long tongue (similar to the giraffe’s) to strip leaves from branches.
# - **Conservation status:** Classified as Endangered due to habitat loss, poaching, and political instability in its native range.
#
# The okapi was unknown to the wider world until the early 20th century and is sometimes called the "forest giraffe" due to its close genetic relationship with the giraffe.
