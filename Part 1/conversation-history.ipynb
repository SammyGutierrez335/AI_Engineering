# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")
else:
    print("Hello World!")

client = OpenAI()
# Out:
# Hello World!

# %% [markdown]
# ### Step 2: Call the API

# %%
responses = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        { "role": "user", "content": "You are a helpful assistant." },
        { "role": "user", "content": "Next week I will be traveling to Spain." }
    ]
)

reply = responses.choices[0].message.content


print(reply)
# Out:
# That sounds exciting! Do you need any help with travel tips, places to visit, or anything related to your trip to Spain?

# %% [markdown]
# ### In Theory...(Doing it manually to demonstrate Psuedo Memory)

# %%
messages=[
        { "role": "user", "content": "You are a helpful assistant." },
        { "role": "user", "content": "Sure I can use tips." },
        { "role": "assistant", "content": "That sounds exciting! Do you need any help with travel tips, places to visit, or anything related to your trip to Spain?"},
        { "role": "user", "content": "Yes, I would like to know the best restaraunts"}
]

responses = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = responses.choices[0].message.content

print(reply)
# Out:
# Great! Spain is famous for its incredible cuisine. Here are some of the best restaurants you might want to try, depending on where you are going:
#
# ### In Madrid:
# 1. **DiverXO** – A three-Michelin-star restaurant by chef David Muñoz, known for innovative and avant-garde dishes.
# 2. **Sobrino de Botín** – Known as the oldest restaurant in the world, famous for traditional Spanish dishes like roasted suckling pig.
# 3. **Mercado de San Miguel** – Not a restaurant but a vibrant food market where you can try a wide variety of tapas and local delicacies.
#
# ### In Barcelona:
# 1. **Tickets** – A famous tapas bar by Albert Adrià, offering creative and modern tapas.
# 2. **Cinc Sentits** – Michelin-starred restaurant with a focus on Catalan cuisine.
# 3. **Cal Pep** – Renowned for its fresh seafood and traditional tapas.
#
# ### In San Sebastián:
# 1. **Arzak** – A three-Michelin-star restaurant focusing on Basque cuisine.
# 2. **Mugaritz** – Innovative and highly acclaimed, perfect for adventurous food lovers.
# 3. **Bar Nestor** – Famous for its tomato salad and chuleta (steak).
#
# ### In Seville:
# 1. **El Rinconcillo** – One of Seville’s oldest tapas bars, great for traditional Andalusian dishes.
# 2. **Egaña-Oriza** – Michelin-starred restaurant with modern Andalusian cuisine.
# 3. **La Azotea** – Popular for creative tapas and a lively atmosphere.
#
# Would you like recommendations based on a specific city or type of cuisine?

# %% [markdown]
# ### In theory...

# %%
messages = [
    { "role": "user", "content": "You are a helpful assistant." },
    {"role": "user", "content": "Sure I can use tips." }
]
responses = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        { "role": "user", "content": "You are a helpful assistant." },
        { "role": "user", "content": "Sure I can use tips." }
        ]
)

reply = responses.choices[0].message.content

print(reply)
# Out:
# Great! Here are some general tips that might help you in various areas:
#
# 1. **Time Management:** Prioritize your tasks using a to-do list or planner. Focus on important and urgent tasks first.
#
# 2. **Productivity:** Take regular breaks using techniques like the Pomodoro Technique (25 minutes work, 5 minutes break) to maintain focus.
#
# 3. **Learning:** Practice active learning by summarizing information in your own words and teaching others.
#
# 4. **Communication:** Listen actively and ask clarifying questions to ensure understanding.
#
# 5. **Health:** Maintain a balanced diet, exercise regularly, and get enough sleep to keep your energy levels up.
#
# If you want tips on a specific topic, just let me know!
