# %% [markdown]
# ### Import Libraries & API Keys

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if OPENAI_API_KEY is None:
    raise Exception("API Key is missing")

# %% [markdown]
# ### Step 2: Searching the Web

# %%
client = OpenAI()
completion = client.chat.completions.create(
    model="gpt-4o-search-mini-preview",
    messages=[
        {"role": "user", 
         "content": """
         What is today's date? Tell me the top 3 stories in the past week related to music, 
         according to reliable news media. Each story should be from a seperate source and date. Include link of sourch and dates.
         """}
    ],
    max_tokens=500
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[22], line 2
#       1 client = OpenAI()
# ----> 2 completion = client.chat.completions.create(
#       3     model="gpt-4o-search-mini-preview",
#       4     messages=[
#       5         {"role": "user",
#
# File ~\Documents\GitHub\AI-Engineering\ai_env\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
search_results = completion.choices[0].message.content
display(Markdown(search_results))
# Out:
# Today's date is June 13, 2024.
#
# Here are the top 3 music-related stories from the past week, each from a different reliable news source and date:
#
# 1. **Billboard (June 12, 2024)**
# *Taylor Swift Breaks Spotify Records with New Album Release*
# Taylor Swift’s latest album release has shattered Spotify’s global streaming records, making it the most-streamed album in a single day in 2024. Industry analysts credit her innovative marketing strategy and loyal fanbase for this remarkable achievement.
#
# 2. **BBC News (June 10, 2024)**
# *Beyoncé Announces World Tour Dates for 2024–2025*
# Beyoncé revealed dates for her upcoming world tour, set to kick off in late 2024. The tour will cover North America, Europe, and Asia, marking her first global tour in over four years. Tickets are expected to sell out rapidly.
#
# 3. **The Guardian (June 8, 2024)**
# *New Study Highlights Impact of Music Therapy on Mental Health*
# ...

# %% [markdown]
# ### Step 3: Summarize and write a social media post

# %%
system_message = """
You are a helpful assistant who creates amazing LinkedIn post about AI on
text that you are provided with. Make the post engaging and interesting.
Also, make concise and add a thought provoking question at the end to encourage comments.
"""

prompt = f"""
The following text contains the top 3 news story pertaining to music in the last week.
Now write my LinkedIn Post based on this information.
{search_results}
"""

completion = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt},
    ], 
    max_tokens=500,
    temperature=.7
)

chat_response = completion.choices[0].message.content

# %%
print(chat_response)
# Out:
# 🎵 Music continues to shape culture, inspire innovation, and even transform health! Here are three powerful stories from the past week in the music world:
#
# 1️⃣ Taylor Swift has once again proven her industry dominance, breaking Spotify’s global streaming record for the most-streamed album in a single day in 2024. Her blend of innovative marketing and a fiercely loyal fanbase is setting new standards for music releases.
#
# 2️⃣ Beyoncé is gearing up for her highly anticipated world tour spanning North America, Europe, and Asia—the first in over four years. This tour is not just a concert series; it’s a global event that reminds us of music’s ability to unite diverse audiences.
#
# 3️⃣ Beyond entertainment, music’s impact on health is gaining scientific validation. A new study highlights how music therapy significantly improves mental health outcomes for those battling depression and anxiety, urging more integration of music in clinical care.
#
# ...
